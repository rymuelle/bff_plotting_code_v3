# %%
from src.assets.output_dir import output_dir
output_dir
asset_dir = output_dir

# %%
import os

# %%
def make_dir(dirstr):
    if os.path.exists(dirstr): return False
    os.mkdir(dirstr)
    return True

# %%
make_dir(asset_dir)
make_dir(asset_dir+"/data")
make_dir(asset_dir+"/data_gen_b_s")
make_dir(asset_dir+"/fits")
make_dir(asset_dir+"/abcd")
make_dir(asset_dir+"/abcd_test")
make_dir(asset_dir+'/abcd_1gev_range')

make_dir(asset_dir+"/stack_plots")
make_dir(asset_dir+"/fits/interp_signal_fit")
make_dir(asset_dir+"/fits/interp_signal_fit/2016/")
make_dir(asset_dir+"/fits/interp_signal_fit/2017/")
make_dir(asset_dir+"/fits/interp_signal_fit/2018/")
make_dir(asset_dir+"/fits/limit_setting/")
make_dir(asset_dir+"/sig_interpolation/")
make_dir(asset_dir+"/output/")
make_dir(asset_dir+"/output/sys_individual_dbs_comp")
make_dir(asset_dir+"/combine_data")
make_dir(asset_dir+"/combine_data/2016")
make_dir(asset_dir+"/combine_data/2017")
make_dir(asset_dir+"/combine_data/2018")
make_dir(asset_dir+"/combine_data/201X")

make_dir(asset_dir+"/limits_gb_dbs_by_mass_reg/")
make_dir(asset_dir+"/limits_gb_dbs_by_mass_reg/201X")
make_dir(asset_dir+"/limits_gb_dbs_by_mass_reg/2016")
make_dir(asset_dir+"/limits_gb_dbs_by_mass_reg/2017")
make_dir(asset_dir+"/limits_gb_dbs_by_mass_reg/2018")
make_dir(asset_dir+"/model_ind/")

make_dir(asset_dir+"/gen_b_s")

make_dir(asset_dir+"/abcd_fit_variations")
