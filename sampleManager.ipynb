# %%
import pandas as pd
from pandas import DataFrame
import numpy as np
from bff_processor.SampleManager import SampleManager

# %%
sample = SampleManager.from_file('data/ZToMuMu_M_50_120.csv')
sample2 = SampleManager.from_file('data/ZToEE_M_50_120.csv')

# %%
sample.print()
sample2.print()
# Out:
# Name: data/ZToMuMu_M_50_120.csv
#  shape: (1742, 26)
#  total: 1.44e+06
#  mass mean: 92.47 std: 7.38
# Name: data/ZToEE_M_50_120.csv
#  shape: (5788, 26)
#  total: 5.78e+05
#  mass mean: 93.45 std: 9.94

# %%
sample_comb = SampleManager.merge([sample,sample2])

# %%
sample_comb.mass_window(100,120).bff(HTLT=-20).print()
# Out:
# Name:
#  shape: (636, 26)
#  total: 1.51e+05
#  mass mean: 110.71 std: 5.61

# %%
n,stat_er, bins, bin_centers = sample_comb.mass_window(-80,120).flag('SR1_nominal').histogram('DiLepMass', bins=np.linspace(50,140,100))

# %%
len(bin_centers), len(stat_er), len(n)
# Out:
# (99, 99, 99)

# %%
import matplotlib.pyplot as plt

# %%
plt.errorbar(bin_centers,n,yerr=stat_er)
# Out:
# <ErrorbarContainer object of 3 artists>

# %%
sample_comb
# Out:
# Name: data/ZToMuMu_M_50_120.csv + data/ZToEE_M_50_120.csv
#  shape: (7530, 26)
#  total: 2.02e+06
#  mass mean: 93.22 std: 9.42
